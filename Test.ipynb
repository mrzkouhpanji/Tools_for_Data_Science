# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# # __Reza Zamani__
# ## _Processs Research and Development_

# %% [markdown]
# _I am a process R&D in semiconductor industry. I see Data Science as a tool to automate fabrication processes troubleshooting and facilitating the process integration. I have been using ML/DL techniques to predict the source of variation (SOV), process failure, and process matching among different fabrication tools._

# %% [markdown]
# The following code calculates the area of a circle after providing the radius.

# %%
def Circle_Area(radius):
    import math
    return math.pi*radius**2

# %%
Circle_Area(1)
# Out:
# 3.141592653589793

# %% [markdown]
# 1. The following words have the same meaning
# - Hello
# - Hi
# - Hey
# ***
# 2. Connect with me in LinkedIn
# [https://www.linkedin.com/in/mrzkouhpanji](http://url)
# ***
# 3. My favorite cat picture
# ![image.jpg](attachment:image.jpg)
# ***
